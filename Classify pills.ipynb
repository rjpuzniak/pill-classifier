# %%
# Import libraries
import numpy as np
import cv2

import torch
import torch.nn as nn

import glob
import os

import matplotlib.pyplot as plt

# %%
import moviepy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-653767589598> in <module>
# ----> 1 import moviepy
#
# ModuleNotFoundError: No module named 'moviepy'

# %%
# Define paths to data
data_folder='/home/rjp/3_Github/Pill_classifier/Data'

# %%
# Define the names of medicine
medicine =[os.path.basename(medicine) for medicine in glob.glob(data_folder+'/*')]
print(medicine)
# Out:
# ['Bactilac', 'Maglek']

# %%
# Define the different training environments
envs = ['white','brown','gray']

# %%
# For given medicine merge all movies
cap = cv2.VideoCapture(data_folder+'/Maglek/Maglek_white_train.mp4')

    from moviepy.editor import VideoFileClip, concatenate_videoclips 
    clip1 = VideoFileClip("myvideo.mp4") 
    clip2 = VideoFileClip("myvideo2.mp4").subclip(50,60) 
    clip3 = VideoFileClip("myvideo3.mp4") 
    final_clip = concatenate_videoclips([clip1,clip2,clip3]) 
    final_clip.write_videofile("my_concatenation.mp4") 

# And create corresponing label structure

# %%
cap.get(7)
# Out:
# 338.0

# %%
# Load the data
cap = cv2.VideoCapture(data_folder+'/Maglek/Maglek_white_train.mp4')
success, image = cap.read()

# Attempt to display using cv2 (doesn't work)
#cv2.namedWindow("Input")
#cv2.imshow("Input", frame)
#cv2.waitKey(0)


#Display image using matplotlib (Works)
b,g,r = cv2.split(image)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)
plt.title('Matplotlib') #Give this plot a title, 
                        #so I know it's from matplotlib and not cv2
plt.show()

# %%
frame_rgb.shape
# Out:
# (1080, 1920, 3)

# %%
plt.hist(frame_rgb[:,:,2].flatten())
# Out:
# (array([7.90000e+01, 4.79300e+03, 8.26770e+04, 3.59666e+05, 1.26814e+06,
#         3.46530e+05, 2.48500e+03, 1.19700e+03, 1.61800e+03, 6.41500e+03]),
#  array([ 30. ,  52.5,  75. ,  97.5, 120. , 142.5, 165. , 187.5, 210. ,
#         232.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
# Split data into frames and create labels

# %%
# Try Otsu's threhsholding method

# %%
#

# %%
import cv2
import matplotlib.pyplot as plt

# Read single frame avi
cap = cv2.VideoCapture('singleFrame.avi')
rval, frame = cap.read()

# Attempt to display using cv2 (doesn't work)
cv2.namedWindow("Input")
cv2.imshow("Input", frame)

#Display image using matplotlib (Works)
b,g,r = cv2.split(frame)
frame_rgb = cv2.merge((r,g,b))
plt.imshow(frame_rgb)
plt.title('Matplotlib') #Give this plot a title, 
                        #so I know it's from matplotlib and not cv2
plt.show()

# %%
import cv2
vidcap = cv2.VideoCapture('big_buck_bunny_720p_5mb.mp4')
success,image = vidcap.read()
count = 0
while success:
  cv2.imwrite("frame%d.jpg" % count, image)     # save frame as JPEG file      
  success,image = vidcap.read()
  print('Read a new frame: ', success)
  count += 1
